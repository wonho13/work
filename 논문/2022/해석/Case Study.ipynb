# %%
# %run functions.ipynb

# %% [markdown]
# ## 주파수 영역

# %%
# Model 선정(quigley2016, Jiang2019 기준)
# (1) OC  (2) SM   (3) alpha.75  (4) Dirlik (5) BT

# %%
# Model : 1 = OC / 2 = SM / 3 = alpha .75 / 4 - Dirlik  / 5 - Benascuitti and Tovo
model =1;
# Duration
dur = 10;

# %% [markdown]
# ## Band Limited White Noise

# %%
# Sample FDS
fmin,fmax,bwp,loc,zeta,m,amp,ovl,model,dur = 1,1000,1,0,0.05,4,1,0,1,10;
model=1;
blwn_test_fd(fmin,fmax,bwp,loc,zeta,m,amp,ovl,model,dur);

# %%
# for all target PSDs
bwp = np.linspace(0.1,1,10);
loc = np.linspace(0,1,11); 
zeta = np.array([0.01,0.02,0.05,0.1]);
m = np.array([4,6,8]);
#ovl = np.linspace(0,0.5,11);
ovl = 0
fmin,fmax= 1,1000;
amp = 1;
for i in range(len(bwp)):
    for j in range(len(loc)):
        for k in range(len(zeta)):
            for x in range(len(m)):                   
                blwn_test_fd(fmin,fmax,bwp[i],loc[j],zeta[k],m[x],amp,ovl,model,dur);

# %%
# Overlap Cases
model=5;
fmin,fmax,bwp,loc,zeta,amp,dur = 1,1000,1,0,0.05,1,10;
ovl=np.linspace(0,0.5,51);
m = np.array([4,6,8]);
zeta = np.array([0.01,0.02,0.05,0.1]);
for i in range(len(ovl)):
    for j in range(len(m)):
        for k in range(len(zeta)):
            blwn_test_fd(fmin,fmax,bwp,loc,zeta[k],m[j],amp,ovl[i],model,dur);

# %% [markdown]
# ## Unimodal

# %%
# Sample FDS
model=1;
fmin,fmax,bwp,loc,fn1,zeta1,z,mm,amp,ovl,dur = 1,1000,1,0,500.5,0.05,0.05,4,1,0,10;
unimodal_test_fd(fmin,fmax,bwp,loc,fn1,zeta1,z,mm,amp,ovl,model,dur);

# %%
# for all target PSDs
bwp = 1; loc = 0; 
fn1 = np.linspace(200,800,13); zeta1 = np.array([0.01,0.02,0.05,0.1]);
fmin = 1; fmax = 1000;
zeta = np.array([0.01,0.02,0.05,0.1]);
m = np.array([4,6,8]);
ovl = 0
fmin,fmax= 1,1000;
amp = 1;
for i in range(len(fn1)):
    for j in range(len(zeta1)):
        for k in range(len(zeta)):
            for x in range(len(m)):                   
                unimodal_test_fd(fmin,fmax,bwp,loc,fn1[i],zeta1[j],zeta[k],m[x],amp,ovl,model,dur);

# %%
# Overlap Cases
model=5;
fmin,fmax,bwp,loc,fn1,zeta1,amp,dur = 1,1000,1,0,500.5,0.05,1,10;
ovl=np.linspace(0,0.5,51);
m = np.array([4,6,8]);
zeta = np.array([0.01,0.02,0.05,0.1]);
for i in range(len(ovl)):
    for j in range(len(m)):
        for k in range(len(zeta)):
            unimodal_test_fd(fmin,fmax,bwp,loc,fn1,zeta1,zeta[k],m[j],amp,ovl[i],model,dur);

# %% [markdown]
# ## Bimodal

# %%
# Sample FDS
model=5;
fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,z,mm,amp,ovl,dur = 1,1000,1,0,300,0.02,700,0.04,1,0.05,4,1,0,10;
bimodal_test_fd(fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,z,mm,amp,ovl,model,dur);

# %%
# for all target PSDs
bwp = 1; loc = 0; fn1 = np.linspace(200,800,4); fn2 = np.linspace(200,800,4); 
zeta1 = np.array([0.01,0.02,0.05,0.1]);
zeta2 = np.array([0.01,0.02,0.05,0.1]);
ovl=0; 
ratio = np.array([0.5,1,2]);
zeta = np.array([0.01,0.02,0.05,0.1]);
m = np.array([4,6,8]);
fmin,fmax= 1,1000;
amp = 1;
for i in range(len(fn1)):
    for j in range(len(zeta1)):
        for k in range(len(fn2)):
            if k > i:
                for x in range(len(zeta2)):
                    for y in range(len(ratio)):
                        for z in range(len(zeta)):
                            for p in range(len(m)):
                                bimodal_test_fd(fmin,fmax,bwp,loc,fn1[i],zeta1[j],fn2[k],zeta2[x],ratio[y],zeta[z],m[p],amp,ovl,model,dur);

# %%
# maximum fatigue damage ratio case
model = 1;
fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,z,mm,amp,ovl,dur = 1,1000,1,0,200,0.01,400,0.05,0.5,0.02,8,1,0,10;
bimodal_test_fd(fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,z,mm,amp,ovl,model,dur);

# %%
# Overlap Cases
model=5;
fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,amp,dur = 1,1000,1,0,300,0.02,700,0.04,1,1,10;
ovl=np.linspace(0,0.5,51);
m = np.array([4,6,8]);
zeta = np.array([0.01,0.02,0.05,0.1]);
for i in range(len(ovl)):
    for j in range(len(m)):
        for k in range(len(zeta)):
            bimodal_test_fd(fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,zeta[k],m[j],amp,ovl[i],model,dur);

# %% [markdown]
# ## 시간 영역

# %% [markdown]
# ## Band Limited White Noise

# %%
# Sample FDS
fmin,fmax,bwp,loc,zeta,m,amp,ovl,dur = 1,1000,1,0,0.05,4,1,0,10;
blwn_test_td(fmin,fmax,bwp,loc,zeta,m,amp,ovl,dur)
# Out:
#
#  Number of   Samples per   Time per        df
#  Segments     Segment      Segment(sec)   (Hz)   dof
#        1 	   131072 	       6.55       0.153    2
#        3 	    65536 	       3.28       0.305    6
#        6 	    32768 	       1.64        0.61    12
#       12 	    16384 	      0.819        1.22    24
#       24 	     8192 	       0.41        2.44    48
#       48 	     4096 	      0.205        4.88    96
#       97 	     2048 	      0.102        9.77    194
#      195 	     1024 	     0.0512        19.5    390
#      390 	      512 	     0.0256        39.1    780
#      781 	      256 	     0.0128        78.1    1562
#     1562 	      128 	     0.0064         156    3124
#
#      number of segments   NW= 24
#        samples/segments  mmm= 8192
#  half samples/segment-1   mH=4095
#
#         df= 2.441 Hz
#
#  Number of   Samples per   Time per        df
#  Segments     Segment      Segment(sec)   (Hz)   dof
#        1 	    65536 	       6.52       0.153    2
# ...

# %% [markdown]
# ## Unimodal

# %%
# Sample FDS
fmin,fmax,bwp,loc,fn1,zeta1,z,mm,amp,ovl,dur = 1,1000,1,0,500.5,0.05,0.05,4,1,0,10;
unimodal_test_td(fmin,fmax,bwp,loc,fn1,zeta1,z,mm,amp,ovl,dur);

# %% [markdown]
# ## Bimodal

# %%
# Sample FDS
fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,z,mm,amp,ovl,dur = 1,1000,1,0,300,0.02,700,0.04,1,0.05,4,1,0,10;
bimodal_test_td(fmin,fmax,bwp,loc,fn1,zeta1,fn2,zeta2,ratio,z,mm,amp,ovl,dur);
