# %% [markdown]
# ## Chapter 1

# %% [markdown]
# # Introduction

# %% [markdown]
# # 1.1 수학적 최적화란 무엇인가?

# %% [markdown]
# 수학적 최적화란 다음을 의미한다.
#
# (i) 공식을 세우는것
#
# (ii) 다음과 같은 형태의 구속조건이 있는 최적화 문제의 해를 구하는것

# %% [markdown]
# $$\begin{align}\min_{w.r.t.\;x}
# f(\mathbf{x}),
# \;\mathbf{x} = [x_1,x_2,\dots,x_n]^T \in \mathbb{R}^n \end{align}$$

# %% [markdown]
# 구속조건들

# %% [markdown]
# $$g_j(\mathbf{x}) \leq 0,\;j=1,2,\dots,m$$
#
# $$h_j(\mathbf{x}) = 0,\; j=1,2,\dots,r \tag{1.1}$$

# %% [markdown]
# 참고로 w.r.t는 with respect to의 약자로 "~에 대하여"를 의미한다.

# %% [markdown]
# $f(\mathbf{x}),\; g_j(\mathbf{x}), \;h_j(\mathbf{x})$는 실수벡터 $\mathbf{x}$에 대한 스칼라 함수이다.

# %% [markdown]
# $\mathbf{x}=[x_1,x_2,\dots,x_n]^T$의 연속적인 성분인 $x_i$는 (설계)변수라고 하며, $f(\mathbf{x})$는 목적함수, $g_j(\mathbf{x})$는 부등구속함수, $h_j(\mathbf{x})$는 동등구속함수라고 한다.

# %% [markdown]
# 문제 (1.1)을 풀어 계산된 최적의 벡터 $\mathbf{x}$를 $\mathbf{x}^*$로 표기하며, 그에 해당하는 최적의 함수 값을 $f(\mathbf{x}^*)$로 표기한다. 구족조건이 없는 경우 이 문제를 "구속되지 않은 최소화 문제"라고 한다.

# %% [markdown]
# 수학적 최적화는 비선형프로그래밍, 수학적프로그래밍, 수치최적화 등으로도 불린다. 더 일반적인 용어로써의 수학적 최적화는 물리적 현상, 생산공정, 경영시스템 등의 최적의 해를 찾는 문제를 의미한다. 첫번째 경우의 해는 최소한의 에너지로 무언가를 생산 해내는 것을 의미하며 과학 및 공학 분야에서 적용된다. 두번째 경우는 상업이나 제정적인 경우로 경제와 연관되며 최소한의 비용으로 최고의 이득을 얻어내도록 결정하는 과정을 의미하게 된다.

# %% [markdown]
# 다양한 변수를 고려하는 수학적 최적화의 역사는 그리 오래 되지 않았으며, 약 70년 정도가 된다. 1940년대 말에 선형프로그래밍 문제의 특수한 경우를 풀기위한 매우 중요하고 단순한 방법이 개발되었다. 그 이후로 일반적인 형태인 식(1.1)을 풀기위한 다양한 방법들이 개발되고 시험되어 많은 중요한 과학 및 경제 분야 적용되어오고 있다.

# %% [markdown]
# 컴퓨터의 등장으로 인해 이러한 최적화 방법들이 더욱 발전하였다. 하지만 모든 최적화 문제를 푸는 방법은 없다. Nocedal과 Wright (1999)에 따르면 "... 수많은 알고리즘들이 있고, 각 알고리즘들은 특정 종류의 최적화 문제에 적합하게 개발된 것이다.  사용하기에 적합한 최적화 알고리즘을 고르는 것은 사용자의 몫이다. 이 선택은 중요하다.  이 선택에 따라 문제가 빨리 풀릴지, 느리게 풀릴지가 결정되며, 해가 찾아질지 안찾아 질지도 결정되기 때문이다." 이와 유사하게 Vanderplatts (1998)은 다음과 같이 말했다. "각 알고리즘의 개발자들은 그 방법의 정확성 및 효율서을 보여줄 수 있는 수치 예제들을 가지고 있다. 그리고 의심이 없는 실무자들은 종종 알고리즘이 특정 문제를 해결하지 못한다는 것을 찾는데 많은 시간과 노력을 쏟는다. 이는 사용자가 수치 최적화에 대한 기본적인 개념을 알고 있으면 피할 수 있는 상황이다." 이러한 대표적이고 권위있는 의견들을 포함, 알고리즘을 개발할 때 저자가 겪은 경험을 고려하여 간략하면서도 통합적인 최적화 개념 및 방법에 대한 소개를 위해 이 책을 쓰게 되었다.  그리고 저자와 저자의 학생들 (Pretoria 대학)이 지난 13년간 개발한 알고리즘들에 대해서도 소개할 것이다.

# %% [markdown]
# 이 책은 경사 기반의 방법을 주로 다룬다. 이는 두가지 이유 때문인데, 첫째는 저자는 전통적인 경사 기반의 방법에 대해 학습하는것이 수학적 최적화를 소개하는데 가장 적합하다고 생각한다는 것이고, 둘째는 요즘 유명한 비경사 방법들은 (예를들면 genetic algorithm, simulated annealing, particle swarm optimization, 그리고 다른 진화 방법들) 대부분 계산량이 많기 때문이다. 수치적 잡음이 있거나 여러개의 최소값이 있는 경우 경사기반 방법의 결과가 좋지않아 앞서말한 방법들을 써야만 해결된다는 논쟁이 있지만 이는 사실이 아니다. 저자의 경험 상 경사 기반의 방법을 적절히 사용하면 수치적 잡음이나 여러개의 최소값 문제를 해결할 수 있다. 이 책의 6장에서는 첫번째 저자가 개발한 새로운 경사 기반의 방법을 다루며, 8장에서는 경사만을 사용하는 방법들에 대해 다루는데 이들은 특히 중요하다. (중략)

# %% [markdown]
# # 1.2 목적함수 및 구속함수

# %% [markdown]
# 특정 점 $\mathbf{x}=[x_1,x_2,\dots,x_n]^T$에서 함수들 $f(\mathbf{x}),\;g_j(\mathbf{x}),\;h_j(\mathbf{x})$의 값들은 다양한 방법으로 계산할 수 있다.

# %% [markdown]
# (i) 해석적으로 알려진 공식 사용. 예를들면 $f(\mathbf{X})=x_1^2+2x_2^2+sinx_3$ 를 사용.

# %% [markdown]
# (ii) 복잡한 계산 절차를 통해 산출.
#
# 예를들면 $g_1(\mathbf{x})=a(\mathbf{x})-a_{max}$를 사용.
#
# 여기서 $a(\mathbf{x})$는 유한요소 해석으로 계산한 특정지점의 응력이며, 그 지점은 벡터 $\mathbf{x}$ 로 정의함.

# %% [markdown]
# (iii) 실제로 측정된 값을 사용
#
# 예를들면 $h_1(\mathbf{x})=T(\mathbf{x})-T_0$ 를 사용.
#
# 여기서 $T(\mathbf{x})$는 원자로의 특정 지점에서 측정한 온도이며, $\mathbf{x}$는 운전 설정치를 벡터로 정의한 것임.

# %% [markdown]
# (i)과 (ii)가 가장 일반적인 방법이다. 이들 경우에 적용하는 최적화의 원리는 실제로 측정한 값들에 직접 적용이 가능하다.

# %% [markdown]
# 최적화 문제의 일반 형태인 (1.1)을 풀기위한 다양한 방법들이 개발되어 왔다. 어떤 경우는 해가 해석적으로 구해질 수 있다. 즉 닫힌 형태의 공식화된 해를 얻을 수 있다.

# %% [markdown]
# 일반적으로, 특히 $n>2$인 경우, 적절한 알고리즘을 사용해 수치적으로 해를 계산할 수 있다.

# %% [markdown]
# (1.1) 형태의 최적화 문제에 적합한 공식은 경험을 통해 얻을 수 있다. 이러한 과정을 수학적 모델링 과정이라고 한다. 요약하면, 실제 상황의 문제를 수학적 모델링으로 풀기위해서는 그림1.1에 나타난 4가지 단계를 수행해야 한다. 주요한 단계는 다음과 같다.
#
# 1) 실제 문제와 관련된 상황을 관찰하고 학습
#
# 2) 고정된 사전 모델 변수 $\mathbf{p}$와 변수 $\mathbf{x}$를 사용한 수학적 모델링을 통해 문제를 정의
#
# 3) 해석적 또는 수치적 해 $\mathbf{x}^*(\mathbf{p})$를 계산
#
# 4) 해 $\mathbf{x}^*(\mathbf{p})$를 평가

# %% [markdown]
# 4) 단계를 마치면 변수들을 조절하고 모델을 재가공하여 새로운 수학적 문제를 정의하고 풀어나가야 한다. 이러한 과정을 여러번 반복하여 원하는 해를 얻어야 한다. 대부분의 경우 3)의 과정은 수치적 방법이 요구되는 수학적 최적화 문제이다. 최적화 문제를 적절히 설정하는 것은 가장 중요하지만 안타깝게도 실제 수학적 최적화 과정에서 무시되는 경우가 많다.

# %% [markdown]
# 이 책에서는 최적화 문제를 어떻게 설정하는지 간략히 소개하고 다양항 최적화 알고리즘들에 대해 상세히 다룰 것이다. 모든 분류의 문제에 일반적으로 적용가능한 알고리즘은 없기 때문에 다양한 구체적인 문제에 대하여 적절한 알고리즘을 고르는 방법에 대해 자세히 다룰 것이다.

# %% [markdown]
# <img src='fig1.1.png'>

# %% [markdown]
# <h3><center>그림 1.1 수학적 모델링 절차</center></h3>

# %% [markdown]
# <img src='fig1.2.png'>

# %% [markdown]
# <h3><center>그림 1.2 $x^*$에서 최적의 값을 갖는 단일변수 함수</center><h3>

# %% [markdown]
# # 1.3 기초적인 최적화 개념

# %% [markdown]
# ## 1.3.1 가장 단순한 문제: 비구속 1차원 최소화 문제

# %% [markdown]
# 다음과 같이 부드러우면서 즉 연속이면서 두번 미분가능한 한개의 실수를 변수로 갖는 함수를 고려해보자.

# %% [markdown]
# $$ \begin{align} \min_{x}f(x),\;x\in \mathbb{R},\;f\in C^2 \tag{1.2} \end{align}$$

# %% [markdown]
# 참고로 $f\in C^2$는 두번 미분 가능한 함수임을 의미

# %% [markdown]
# 그림 1.2를 보면, 모든 $x$에 대하여 $f(x^*)<f(x)$를 만족하는 $x^*$를 찾아야 한다.

# %% [markdown]
# $x^*$는 기울기가 0인 지점에서의 값이다. 즉,

# %% [markdown]
# $$f'(x)=\frac{df(x)}{dx}=0$$

# %% [markdown]
# 이를 1차 필수 조건이라고 한다. 또한 $x^*$에서의 곡률값은 0보다 커야한다. 이를 2차 필수 조건이라고 하며 다음과 같다.

# %% [markdown]
# $$f''(x)=\frac{d^2f(x)}{dx^2}>0$$

# %% [markdown]
# 다음과 같이 $f(x)$가 2차 함수인 경우를 생각해보자.

# %% [markdown]
# $$f(x)=ax^2+bx+c \tag{1.3}$$

# %% [markdown]
# 최소값은 $f'(x)=0$에서 발생하기 때문에 닫힌 형태의 해는 다음과 같이 주어진다.

# %% [markdown]
# $$x^*=-\frac{b}{2a},\; f''(x^*)=2a>0 \tag{1.4}$$

# %% [markdown]
# 만약 $f(x)$가 더 일반적인 형태라면 닫힌 형태의 해는 일반적으로 계산이 불가능하다. 이러한 경우 Newton-Raphson 알고리즘을 사용해 수치적인 해를 구할 수 있다.

# %% [markdown]
# 초기 추정값 $x^0$을 정의하고 다음의 계산을 반복한다.

# %% [markdown]
# $$x^{i+1}=x^i-\frac{f'(x^i)}{f''(x^i)}; \; i=0,1,2,\dots \tag{1.5}$$

# %% [markdown]
# 유한한 횟수의 반복을 통해 충분히 정확한 수치적 해를 얻을 수 있다. 즉 위의 과정은 수렴하여 $\begin{align}\lim_{i \to \infty}x^i=x^*\end{align}$이 된다.

# %% [markdown]
# ## 1.3.2 2개 변수(n=2) 함수의 등고선(contour) 표현

# %% [markdown]
# 두개의 변수 $\mathbf{x}=[x_1,x_2]^T$에 대한 함수 $f(\mathbf{x})$를 고려해보자.

# %% [markdown]
# $f(\mathbf{x})=c=상수$를 만족하는 모든 점들은 $x_1-x_2$평면에서 등고선을 형성한다. 다양한 $c$ 값들에 대해 다양한 등고선이 작성될 수 있다.

# %% [markdown]
# 그림 1.3은 $f(\mathbf{x})=x_1^2+2x_2^2$인 경우의 등고선을 보여준다.

# %%
from numpy import *
from matplotlib.pyplot import *
x1,x2 = meshgrid(linspace(-3,3,1000),linspace(-3,3,1000)); fx = x1**2+2*x2**2; 
fig = figure(figsize=(5,5)); ax = fig.add_subplot(1,1,1);
ax.spines['left'].set_position('center'); ax.spines['bottom'].set_position('center');
ax.spines['right'].set_color('none'); ax.spines['top'].set_color('none');
contour(x1,x2,fx,levels=[1,4]); xlabel('$x_1$'); ax.xaxis.set_label_coords(1.05, 0.45);
h=ylabel('$x_2$'); h.set_rotation(0); ax.yaxis.set_label_coords(0.55, 1);
text(0.6,0.6,'$c=1$'); text(1.2,1.2,'$c=4$');

# %% [markdown]
# <h3>그림 1.3 $f(\mathbf{x})=x_1^2+2x_2^2$의 등고선 표현 </h3>

# %% [markdown]
# 3차원(n = 3)의 경우 등고선은 상수인 함수값에 대한 표면으로 표현된다. 3차원 이상(n > 3)인 경우는 등고선의 시각화가 불가능하다. 그럼에도 불구하고 2차원 공간에서의 등고선 표현을 사용하여 다양한 최적화 개념을 설명할 것이다.

# %% [markdown]
# 2차원 목적함수에 대한 등고선 예시들이 그림 1.4에서 1.6에 나타나 있다.

# %%
x1,x2 = meshgrid(linspace(-10,10,1000),linspace(-10,10,1000)); fx = (-x1+2*x2-2)**2+(-2*x1+x2-2)**2 
fig = figure(figsize=(7,7)); ax = fig.add_subplot(1,1,1);
contour(x1,x2,fx,levels = [0.25,1,2,4,8,20,50,100],colors='black'); xlabel('$x_1$'); ylabel('$x_2$');

# %% [markdown]
# <h3>그림 1.4 일반적인 2차원 함수</h3>

# %%
x1,x2 = meshgrid(linspace(-2,2,1000),linspace(-1,4,1000)); fx = 10*(x2-x1**2)**2+(1-x1)**2 
fig = figure(figsize=(7,10)); ax = fig.add_subplot(1,1,1);
CS=contour(x1,x2,fx,levels = [0.25,1,2,4,8,20,50,100],colors='black'); xlabel('$x_1$'); ylabel('$x_2$'); 
clabel(CS, CS.levels, inline=True,fmt='%3.0d', fontsize=10);
arrow(0.2,1.8,0.7,-0.7,overhang=0, head_width=0.1, head_length=0.15,color='k');
text(-0.3,2.1,'Optimum',fontsize=12); text(-0.3,1.9,'$f(x)=0.0$',fontsize=12);

# %% [markdown]
# <h3>그림 1.5 2차원 Rosenbrock 함수 $f(\mathbf{x})=10(x_2-x_1^2)^2-(1-x_1)^2$</h3>

# %% [markdown]
# <h2>(생략)</h2>

# %% [markdown]
# <h3>그림 1.6 스프링 하중 시스템의 잠재 에너지 함수 (Vander-Plaats 1998) </h3>

# %% [markdown]
# ## 1.3.3 구속 함수의 등고선 표현

# %% [markdown]
# ### 1.3.3.1 부등 구속 함수 $g(\mathbf{x})$

# %% [markdown]
# $g(\mathbf{x}) \leq 0$인 전형적인 부등 구속 함수 $g(\mathbf{x})$에 대한 등고선이 그림 1.7에 나타나 있다. $g(\mathbf{x})=0$인 등고선은 평면을 가능한(feasible) 구역과 불가능한(infeasible) 구역으로 나눈다.

# %% [markdown]
# 일반적으로 $n>3$이면 저 경계는 3차원이며, 하이퍼평면(hyper-surface)이라고 부른다.

# %%
x1,x2 = meshgrid(linspace(-4,5,1000),linspace(-3,4,1000));  gx = (x1/2-6.5)**2+(x2/1.5-2.5)**2-50; 
fig = figure(figsize=(5,5)); ax = fig.add_subplot(1,1,1); ylim(-4,5); xlim(-5,5);
ax.spines['right'].set_color('none'); ax.spines['top'].set_color('none');
contour(x1,x2,gx,levels=[-15,-10,-5,0,5,10,15]); 
xlabel('$x_1$'); ax.xaxis.set_label_coords(1.05, 0);
h=ylabel('$x_2$'); h.set_rotation(0); ax.yaxis.set_label_coords(0, 1.02);
text(-3.4,4.2,'15'); text(-2.6,4.2,'10'); text(-2,4.2,'5'); text(-1.7,4.6,'$g(\mathbf{x})=0$');
text(-0.6,4.2,'-5'); text(0.2,4.2,'-10'); text(1,4.2,'-15');
text(-4.5,1,'(infeasible region)'); text(-3.6,0.5,'$g(\mathbf{x})>0$');
text(0,1,'(feasible region)'); text(0.7,0.5,'$g(\mathbf{x})<0$');
arrow(-2.5,-1,1.9,0.9,overhang=0, head_width=0.3, head_length=0.3,color='k');
text(-4.8,-1.2,'Boundary of'); text(-4.8,-1.6,'feasible region');

# %% [markdown]
# <h3> 그림 1.7 가능(feasible) 및 불가능(infeasible) 영역에 포함되는 등고선

# %% [markdown]
# ### 1.3.3.2 동등 구속 함수 $h(\mathbf{x})$

# %% [markdown]
# 그림 1.8에 나타난 바와 같이 $h(\mathbf{x})=0$에서만 feasible 하다.

# %%
x1,x2 = meshgrid(linspace(-4,5,1000),linspace(-3,4,1000));  gx = (x1/2-6.5)**2+(x2/1.5-2.5)**2-50; 
fig = figure(figsize=(5,5)); ax = fig.add_subplot(1,1,1); ylim(-4,5); xlim(-5,5);
ax.spines['right'].set_color('none'); ax.spines['top'].set_color('none');
contour(x1,x2,gx,levels=[-15,-10,-5,0,5,10,15]); 
xlabel('$x_1$'); ax.xaxis.set_label_coords(1.05, 0);
h=ylabel('$x_2$'); h.set_rotation(0); ax.yaxis.set_label_coords(0, 1.02);
text(-3.4,4.2,'15'); text(-2.6,4.2,'10'); text(-2,4.2,'5'); text(-1.7,4.6,'$h(\mathbf{x})=0$');
text(-0.6,4.2,'-5'); text(0.2,4.2,'-10'); text(1,4.2,'-15');
arrow(-2.5,-1,1.9,0.9,overhang=0, head_width=0.3, head_length=0.3,color='k');
text(-4.8,-1.2,'Feasibile contour'); text(-4.8,-1.6,'(feasible surface)');

# %% [markdown]
# <h3> 그림 1.8 동등 구속 함수의 가능(feasible) 등고선

# %% [markdown]
# ## 1.3.4 구속 최적화 문제의 등고선 표현

# %% [markdown]
# ### 1.3.4.1 부등 구속 문제의 표현

# %% [markdown]
# 그림 1.9는 부등 구속 문제를 나타낸다.

# %%
x1,x2 = meshgrid(linspace(-100,100,1000),linspace(-100,100,1000)); fx = sqrt((x1)**2+(x2)**2); 
gx = sqrt((x1-41)**2+(x2-10)**2); 
fig = figure(figsize=(7,7)); ax = fig.add_subplot(1,1,1);
ax.spines['left'].set_color('none'); ax.spines['bottom'].set_color('none');
ax.spines['right'].set_color('none'); ax.spines['top'].set_color('none');
contour(x1,x2,fx,levels=[5,10,15,20]);
contour(x1,x2,gx,levels=[30]);
xticks([], []); yticks([], []);
xlim(-25,25); ylim(-25,25);
plot(0,0,'ko',ms=13); plot(11.5,5,'ko',ms=13); 
arrow(-16,-16,14,14,overhang=0, head_width=1, head_length=2,color='k');
arrow(17,15,-4,-7,overhang=0, head_width=1, head_length=2,color='k');
text(16,25,'$g(\mathbf{x})=0$',size=12);
text(-28,-19,'unconstrained \nminimum',size=12);
text(17.5,15,'$\mathbf{x}^*;\;f(\mathbf{x}^*)=12$ \n(constrained minimum)',size=12);
text(22,-8,'$g(\mathbf{x})<0$ \n(feasible region)',size=12);
text(10,-18,'$g(\mathbf{x})>0$ \n(infeasible region)',size=12);
for i in range(5): text(-i,i*5+1,'$f=%d$'%(i*5),size=12);

# %% [markdown]
# <h3> 그림 1.9 부등 구속 문제의 등고선 표현 </h3>
